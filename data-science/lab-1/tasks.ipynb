# %%
# Task 1
name = input("Enter your name: ")
age = int(input("Enter your age: "))
dept = input("Enter your department: ")
sem = int(input("Enter your semester: "))

print(f"Student Name: {name} \nStudent Age: {age} \nStudent Department: {dept} \nStudent Semester: {sem}")
# Out:
# Student Name: Naveed
# Student Age: 23
# Student Department: CS
# Student Semester: 6

# %%
# Task 2
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print(f"Addition: {num1 + num2} \nSubtraction: {num1 - num2} \nMultiplication: {num1 * num2} \nDivision: {num1 / num2}")
# Out:
# Addition: 10
# Subtraction: 0
# Multiplication: 25
# Division: 1.0

# %%
# Task 3
num = int(input("Enter a number: "))

if num == 0:
    print("Number is zero")
elif num > 0:
    print("Number is positive")
else:
    print("Number is negative")
# Out:
# Number is positive

# %%
# Task 4
num4 = int(input("Enter a number: "))

if num4 % 2 == 0:
    print("Number is even")
else:
    print("Number is odd")
# Out:
# Number is even

# %%
# Task 5
num5 = int(input("Enter your marks: "))

if num5 >= 80:
    print("Grade: A")
elif num5 >= 70:
    print("Grade: B")
elif num5 >= 60:
    print("Grade: C")
elif num5 >= 50:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Grade: A

# %%
# Task 6
student_bio = {
    "Name": "Naveed Amar Guriro",
    "Age": 22,
    "Department": "Computer Science",
    "Semester": 6,
    "GPA" : 3.5
    }

student_bio.values()
student_bio.keys()
# Out:
# dict_keys(['Name', 'Age', 'Department', 'Semester', 'GPA'])

# %%
# Task 7
subjects = ["ML", "DL", "NLP", "OS"]
subjects.remove("OS")
subjects.append("AI")
print(subjects)
# Out:
# ['ML', 'DL', 'NLP', 'AI']

# %%
# Task 8
marks = int(input("Enter your marks: "))

if marks >= 80:
    print("Excellent Marks")
elif marks >= 60:
    print("Good Marks")
elif marks >= 50:
    print("Average Marks")
else:
    print("Needs Improvement")
# Out:
# Excellent Marks

# %%
# Task 9
stud_name = input("Enter name: ")
roll_no = int(input("Enter roll no: "))
subs_count = int(input("Enter number of subjects: "))
subs_marks = []


for i in range(subs_count):
    sub_marks = int(input(f"Enter marks for subject {i+1}: "))
    subs_marks.append(sub_marks)

total_marks = 100 * subs_count
marks_obtained = sum(subs_marks)
avg_marks = total_marks / subs_count
percent = (marks_obtained * 100) / total_marks

if percent >= 80:
    grade = 'A'
elif percent >= 70:
    grade = 'B'
elif num5 >= 60:
    grade = 'C'
elif num5 >= 50:
    grade = 'D'
else:
    Grade =  'F'

print(f"Student Name: {stud_name} \nRoll No: {roll_no} \nTotal Marks: {total_marks} \nMarks Obtained: {marks_obtained} \nAverage Marks: {avg_marks} \nPercentage: {percent} \nGrade: {grade}")
# Out:
# Student Name: Naveed
# Roll No: 38
# Total Marks: 300
# Marks Obtained: 221
# Average Marks: 100.0
# Percentage: 73.66666666666667
# Grade: B
