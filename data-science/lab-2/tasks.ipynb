# %%
from random import randint

students =["Ali", "Ahmed", "Sara"]
for student in students:
    print(student)
# Out:
# Ali
# Ahmed
# Sara

# %%
for number in range(1,6):
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
number = int(input("Enter a number: "))

for _ in range(10):
    print(f"{number} x {_+1} = {number*(_+1)}")
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %%
for i in range(5):
    print("*"*i)
# Out:
# *
# **
# ***
# ****

# %%
name = "Naveed"
for i in  range(len(name)):
    print(name[i])
# Out:
# N
# a
# v
# e
# e
# d

# %%
a = int(input("enter a: "))
b = int(input("enter b: "))

def sum(a,b):
    return a + b

print(sum(a,b))
# Out:
# 9

# %%
numbers = lambda x: x*x
print(numbers)
# Out:
# <function <lambda> at 0x7fec0cdd3a00>

# %%
number = [1,2,3,4,5]
even_number = list(filter(lambda x: x % 2 ==1 , number))
print(even_number)
# Out:
# [1, 3, 5]

# %%
import math
print(math.sqrt(2))
# Out:
# 1.4142135623730951

# %%
import random
random_no = random.randint(1,100)
print(random_no)
# Out:
# 20

# %%
rand_num = random.randint(1,10)
while True:
    guess = int(input("Enter your guess"))
    if guess == random_no:
        print("your guess is correct")
        break
    elif guess < random_no:
        print("your guess is lower")
    else:
        print("guess is higher")
# Out:
# your guess is lower
# your guess is lower
# your guess is lower
# your guess is lower
# your guess is lower
# your guess is lower
# your guess is lower
# your guess is lower
# your guess is lower
# your guess is lower
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 3
#       1 rand_num = random.randint(1,10)
#       2 while True:
# ----> 3     guess = int(input("Enter your guess"))
#       4     if guess == random_no:
#       5         print("your guess is correct")
#       6         break
#
# File ~/OneDrive/Current/Bahria-University-Labs/.venv-linux/lib64/python3.14/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/OneDrive/Current/Bahria-University-Labs/.venv-linux/lib64/python3.14/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
